# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('car data.csv')

# %%
df.head()
# Out:
#   Car_Name  Year  Selling_Price  Present_Price  Kms_Driven Fuel_Type  \
# 0     ritz  2014           3.35           5.59       27000    Petrol
# 1      sx4  2013           4.75           9.54       43000    Diesel
# 2     ciaz  2017           7.25           9.85        6900    Petrol
# 3  wagon r  2011           2.85           4.15        5200    Petrol
# 4    swift  2014           4.60           6.87       42450    Diesel
#
#   Seller_Type Transmission  Owner
# 0      Dealer       Manual      0
# 1      Dealer       Manual      0
# 2      Dealer       Manual      0
# 3      Dealer       Manual      0
# 4      Dealer       Manual      0

# %%
df.shape
# Out:
# (301, 9)

# %%
print(df['Seller_Type'].unique())
# Out:
# ['Dealer' 'Individual']

# %%
print(df['Fuel_Type'].unique())
# Out:
# ['Petrol' 'Diesel' 'CNG']

# %%
print(df['Transmission'].unique())
# Out:
# ['Manual' 'Automatic']

# %%
print(df['Car_Name'].unique())
# Out:
# ['ritz' 'sx4' 'ciaz' 'wagon r' 'swift' 'vitara brezza' 's cross'
#  'alto 800' 'ertiga' 'dzire' 'alto k10' 'ignis' '800' 'baleno' 'omni'
#  'fortuner' 'innova' 'corolla altis' 'etios cross' 'etios g' 'etios liva'
#  'corolla' 'etios gd' 'camry' 'land cruiser' 'Royal Enfield Thunder 500'
#  'UM Renegade Mojave' 'KTM RC200' 'Bajaj Dominar 400'
#  'Royal Enfield Classic 350' 'KTM RC390' 'Hyosung GT250R'
#  'Royal Enfield Thunder 350' 'KTM 390 Duke ' 'Mahindra Mojo XT300'
#  'Bajaj Pulsar RS200' 'Royal Enfield Bullet 350'
#  'Royal Enfield Classic 500' 'Bajaj Avenger 220' 'Bajaj Avenger 150'
#  'Honda CB Hornet 160R' 'Yamaha FZ S V 2.0' 'Yamaha FZ 16'
#  'TVS Apache RTR 160' 'Bajaj Pulsar 150' 'Honda CBR 150' 'Hero Extreme'
#  'Bajaj Avenger 220 dtsi' 'Bajaj Avenger 150 street' 'Yamaha FZ  v 2.0'
#  'Bajaj Pulsar  NS 200' 'Bajaj Pulsar 220 F' 'TVS Apache RTR 180'
#  'Hero Passion X pro' 'Bajaj Pulsar NS 200' 'Yamaha Fazer '
#  'Honda Activa 4G' 'TVS Sport ' 'Honda Dream Yuga '
#  'Bajaj Avenger Street 220' 'Hero Splender iSmart' 'Activa 3g'
#  'Hero Passion Pro' 'Honda CB Trigger' 'Yamaha FZ S '
#  'Bajaj Pulsar 135 LS' 'Activa 4g' 'Honda CB Unicorn'
#  'Hero Honda CBZ extreme' 'Honda Karizma' 'Honda Activa 125' 'TVS Jupyter'
#  'Hero Honda Passion Pro' 'Hero Splender Plus' 'Honda CB Shine'
#  'Bajaj Discover 100' 'Suzuki Access 125' 'TVS Wego' 'Honda CB twister'
#  'Hero Glamour' 'Hero Super Splendor' 'Bajaj Discover 125' 'Hero Hunk'
#  'Hero  Ignitor Disc' 'Hero  CBZ Xtreme' 'Bajaj  ct 100' 'i20' 'grand i10'
#  'i10' 'eon' 'xcent' 'elantra' 'creta' 'verna' 'city' 'brio' 'amaze'
#  'jazz']

# %%
print(df['Owner'].unique())
# Out:
# [0 1 3]

# %%
df.isnull().sum()
# Out:
# Car_Name         0
# Year             0
# Selling_Price    0
# Present_Price    0
# Kms_Driven       0
# Fuel_Type        0
# Seller_Type      0
# Transmission     0
# Owner            0
# dtype: int64

# %%
df.describe()
# Out:
#               Year  Selling_Price  Present_Price     Kms_Driven       Owner
# count   301.000000     301.000000     301.000000     301.000000  301.000000
# mean   2013.627907       4.661296       7.628472   36947.205980    0.043189
# std       2.891554       5.082812       8.644115   38886.883882    0.247915
# min    2003.000000       0.100000       0.320000     500.000000    0.000000
# 25%    2012.000000       0.900000       1.200000   15000.000000    0.000000
# 50%    2014.000000       3.600000       6.400000   32000.000000    0.000000
# 75%    2016.000000       6.000000       9.900000   48767.000000    0.000000
# max    2018.000000      35.000000      92.600000  500000.000000    3.000000

# %%
df.drop(['Car_Name'],axis=1,inplace=True)

# %%
df['Current_year']=2020

# %%
df['year_old']=df['Current_year']-df['Year']

# %%
df.head()
df.drop(['Current_year','Year'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0           3.35           5.59       27000    Petrol      Dealer
# 1           4.75           9.54       43000    Diesel      Dealer
# 2           7.25           9.85        6900    Petrol      Dealer
# 3           2.85           4.15        5200    Petrol      Dealer
# 4           4.60           6.87       42450    Diesel      Dealer
#
#   Transmission  Owner  year_old
# 0       Manual      0         6
# 1       Manual      0         7
# 2       Manual      0         3
# 3       Manual      0         9
# 4       Manual      0         6

# %%
df
# Out:
#      Selling_Price  Present_Price  Kms_Driven Fuel_Type Seller_Type  \
# 0             3.35           5.59       27000    Petrol      Dealer
# 1             4.75           9.54       43000    Diesel      Dealer
# 2             7.25           9.85        6900    Petrol      Dealer
# 3             2.85           4.15        5200    Petrol      Dealer
# 4             4.60           6.87       42450    Diesel      Dealer
# 5             9.25           9.83        2071    Diesel      Dealer
# 6             6.75           8.12       18796    Petrol      Dealer
# 7             6.50           8.61       33429    Diesel      Dealer
# 8             8.75           8.89       20273    Diesel      Dealer
# 9             7.45           8.92       42367    Diesel      Dealer
# 10            2.85           3.60        2135    Petrol      Dealer
# 11            6.85          10.38       51000    Diesel      Dealer
# 12            7.50           9.94       15000    Petrol      Dealer
# 13            6.10           7.71       26000    Petrol      Dealer
# 14            2.25           7.21       77427    Petrol      Dealer
# 15            7.75          10.79       43000    Diesel      Dealer
# 16            7.25          10.79       41678    Diesel      Dealer
# 17            7.75          10.79       43000    Diesel      Dealer
# 18            3.25           5.09       35500       CNG      Dealer
# 19            2.65           7.98       41442    Petrol      Dealer
# 20            2.85           3.95       25000    Petrol      Dealer
# 21            4.90           5.71        2400    Petrol      Dealer
# 22            4.40           8.01       50000    Petrol      Dealer
# 23            2.50           3.46       45280    Petrol      Dealer
# 24            2.90           4.41       56879    Petrol      Dealer
# 25            3.00           4.99       20000    Petrol      Dealer
# 26            4.15           5.87       55138    Petrol      Dealer
# 27            6.00           6.49       16200    Petrol  Individual
# 28            1.95           3.95       44542    Petrol      Dealer
# 29            7.45          10.38       45000    Diesel      Dealer
# ..             ...            ...         ...       ...         ...
# 271           3.00          10.00       69562    Petrol      Dealer
# 272           7.50          10.00       27600    Petrol      Dealer
# 273           2.25           7.50       61203    Petrol      Dealer
# 274           5.30           6.80       16500    Petrol      Dealer
# 275          10.90          13.60       30753    Petrol      Dealer
# 276           8.65          13.60       24800    Petrol      Dealer
# 277           9.70          13.60       21780    Petrol      Dealer
# 278           6.00           8.40        4000    Petrol      Dealer
# 279           6.25          13.60       40126    Petrol      Dealer
# 280           5.25           5.90       14465    Petrol      Dealer
# 281           2.10           7.60       50456    Petrol      Dealer
# 282           8.25          14.00       63000    Diesel      Dealer
# 283           8.99          11.80        9010    Petrol      Dealer
# 284           3.50           5.90        9800    Petrol      Dealer
# 285           7.40           8.50       15059    Petrol      Dealer
# 286           5.65           7.90       28569    Petrol      Dealer
# 287           5.75           7.50       44000    Petrol      Dealer
# 288           8.40          13.60       34000    Petrol      Dealer
# 289          10.11          13.60       10980    Petrol      Dealer
# 290           4.50           6.40       19000    Petrol      Dealer
# 291           5.40           6.10       31427    Petrol      Dealer
# 292           6.40           8.40       12000    Petrol      Dealer
# 293           3.25           9.90       38000    Petrol      Dealer
# 294           3.75           6.80       33019    Petrol      Dealer
# 295           8.55          13.09       60076    Diesel      Dealer
# 296           9.50          11.60       33988    Diesel      Dealer
# 297           4.00           5.90       60000    Petrol      Dealer
# 298           3.35          11.00       87934    Petrol      Dealer
# 299          11.50          12.50        9000    Diesel      Dealer
# 300           5.30           5.90        5464    Petrol      Dealer
#
#     Transmission  Owner  year_old
# 0         Manual      0         6
# 1         Manual      0         7
# 2         Manual      0         3
# 3         Manual      0         9
# 4         Manual      0         6
# 5         Manual      0         2
# 6         Manual      0         5
# 7         Manual      0         5
# 8         Manual      0         4
# 9         Manual      0         5
# 10        Manual      0         3
# 11        Manual      0         5
# 12     Automatic      0         5
# 13        Manual      0         5
# 14        Manual      0        11
# 15        Manual      0         4
# 16        Manual      0         5
# 17        Manual      0         4
# 18        Manual      0         5
# 19        Manual      0        10
# 20        Manual      0         4
# 21        Manual      0         3
# 22     Automatic      0         9
# 23        Manual      0         6
# 24        Manual      0         7
# 25        Manual      0         9
# 26        Manual      0         7
# 27        Manual      0         3
# 28        Manual      0        10
# 29        Manual      0         5
# ..           ...    ...       ...
# 271       Manual      0        11
# 272       Manual      0         5
# 273       Manual      0        10
# 274       Manual      0         6
# 275    Automatic      0         4
# 276       Manual      0         5
# 277       Manual      0         5
# 278       Manual      0         4
# 279       Manual      0         6
# 280       Manual      0         5
# 281       Manual      0        14
# 282       Manual      0         6
# 283       Manual      0         4
# 284       Manual      0         7
# 285    Automatic      0         4
# 286       Manual      0         4
# 287    Automatic      0         5
# 288       Manual      0         5
# 289       Manual      0         4
# 290       Manual      0         6
# 291       Manual      0         5
# 292       Manual      0         4
# 293       Manual      0        10
# 294       Manual      0         6
# 295       Manual      0         5
# 296       Manual      0         4
# 297       Manual      0         5
# 298       Manual      0        11
# 299       Manual      0         3
# 300       Manual      0         4
#
# [301 rows x 8 columns]

# %%
df=pd.get_dummies(df,drop_first=True)

# %%
df.head()
# Out:
#    Selling_Price  Present_Price  Kms_Driven  Owner  year_old  \
# 0           3.35           5.59       27000      0         6
# 1           4.75           9.54       43000      0         7
# 2           7.25           9.85        6900      0         3
# 3           2.85           4.15        5200      0         9
# 4           4.60           6.87       42450      0         6
#
#    Fuel_Type_Diesel  Fuel_Type_Petrol  Seller_Type_Individual  \
# 0                 0                 1                       0
# 1                 1                 0                       0
# 2                 0                 1                       0
# 3                 0                 1                       0
# 4                 1                 0                       0
#
#    Transmission_Manual
# 0                    1
# 1                    1
# 2                    1
# 3                    1
# 4                    1

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.pairplot(df)

# %%
corr_mat=df.corr()

# %%
corr_mat
# Out:
#                         Selling_Price  Present_Price  Kms_Driven     Owner  \
# Selling_Price                1.000000       0.878983    0.029187 -0.088344
# Present_Price                0.878983       1.000000    0.203647  0.008057
# Kms_Driven                   0.029187       0.203647    1.000000  0.089216
# Owner                       -0.088344       0.008057    0.089216  1.000000
# year_old                    -0.236141       0.047584    0.524342  0.182104
# Fuel_Type_Diesel             0.552339       0.473306    0.172515 -0.053469
# Fuel_Type_Petrol            -0.540571      -0.465244   -0.172874  0.055687
# Seller_Type_Individual      -0.550724      -0.512030   -0.101419  0.124269
# Transmission_Manual         -0.367128      -0.348715   -0.162510 -0.050316
#
#                         year_old  Fuel_Type_Diesel  Fuel_Type_Petrol  \
# Selling_Price          -0.236141          0.552339         -0.540571
# Present_Price           0.047584          0.473306         -0.465244
# Kms_Driven              0.524342          0.172515         -0.172874
# Owner                   0.182104         -0.053469          0.055687
# year_old                1.000000         -0.064315          0.059959
# Fuel_Type_Diesel       -0.064315          1.000000         -0.979648
# Fuel_Type_Petrol        0.059959         -0.979648          1.000000
# Seller_Type_Individual  0.039896         -0.350467          0.358321
# Transmission_Manual    -0.000394         -0.098643          0.091013
#
#                         Seller_Type_Individual  Transmission_Manual
# Selling_Price                        -0.550724            -0.367128
# Present_Price                        -0.512030            -0.348715
# Kms_Driven                           -0.101419            -0.162510
# Owner                                 0.124269            -0.050316
# year_old                              0.039896            -0.000394
# Fuel_Type_Diesel                     -0.350467            -0.098643
# Fuel_Type_Petrol                      0.358321             0.091013
# Seller_Type_Individual                1.000000             0.063240
# Transmission_Manual                   0.063240             1.000000

# %%
corr_mat.index
# Out:
# Index(['Selling_Price', 'Present_Price', 'Kms_Driven', 'Owner', 'year_old',
#        'Fuel_Type_Diesel', 'Fuel_Type_Petrol', 'Seller_Type_Individual',
#        'Transmission_Manual'],
#       dtype='object')

# %%
plt.figure(figsize=(20,20))
h=sns.heatmap(df.corr(),annot=True,cmap='twilight_shifted')

# %%
X=df.iloc[:,1:]
Y=df.iloc[:,0]

# %%
X.head()
# Out:
#    Present_Price  Kms_Driven  Owner  year_old  Fuel_Type_Diesel  \
# 0           5.59       27000      0         6                 0
# 1           9.54       43000      0         7                 1
# 2           9.85        6900      0         3                 0
# 3           4.15        5200      0         9                 0
# 4           6.87       42450      0         6                 1
#
#    Fuel_Type_Petrol  Seller_Type_Individual  Transmission_Manual
# 0                 1                       0                    1
# 1                 0                       0                    1
# 2                 1                       0                    1
# 3                 1                       0                    1
# 4                 0                       0                    1

# %%
from sklearn.ensemble import ExtraTreesRegressor
model=ExtraTreesRegressor()
model.fit(X,Y)
# Out:
# ExtraTreesRegressor(bootstrap=False, ccp_alpha=0.0, criterion='mse',
#                     max_depth=None, max_features='auto', max_leaf_nodes=None,
#                     max_samples=None, min_impurity_decrease=0.0,
#                     min_impurity_split=None, min_samples_leaf=1,
#                     min_samples_split=2, min_weight_fraction_leaf=0.0,
#                     n_estimators=100, n_jobs=None, oob_score=False,
#                     random_state=None, verbose=0, warm_start=False)

# %%
print(model.feature_importances_)
# Out:
# [3.75833329e-01 3.96804192e-02 3.34174318e-04 7.67757183e-02
#  2.35324092e-01 6.77713250e-03 1.24720390e-01 1.40554745e-01]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,Y_train,Y_test=train_test_split(X,Y,test_size=0.2)

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import RandomizedSearchCV

# %%
rf=RandomForestRegressor()

# %%
#Randomized Search CV

# Number of trees in random forest
n_estimators = [int(x) for x in np.linspace(start = 100, stop = 1200, num = 12)]
# Number of features to consider at every split
max_features = ['auto', 'sqrt']
# Maximum number of levels in tree
max_depth = [int(x) for x in np.linspace(5, 30, num = 6)]
# max_depth.append(None)
# Minimum number of samples required to split a node
min_samples_split = [2, 5, 10, 15, 100]
# Minimum number of samples required at each leaf node
min_samples_leaf = [1, 2, 5, 10]

# %%
# Create the random grid
random_grid = {'n_estimators': n_estimators,
               'max_features': max_features,
               'max_depth': max_depth,
               'min_samples_split': min_samples_split,
               'min_samples_leaf': min_samples_leaf}

print(random_grid)
# Out:
# {'min_samples_split': [2, 5, 10, 15, 100], 'max_features': ['auto', 'sqrt'], 'min_samples_leaf': [1, 2, 5, 10], 'max_depth': [5, 10, 15, 20, 25, 30], 'n_estimators': [100, 200, 300, 400, 500, 600, 700, 800, 900, 1000, 1100, 1200]}

# %%
rf_random = RandomizedSearchCV(estimator = rf, param_distributions = random_grid,scoring='neg_mean_squared_error', n_iter = 10, cv = 5, verbose=2, random_state=42, n_jobs = 1)

# %%
rf_random.fit(X_train,Y_train)
# Out:
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV] min_samples_split=5, max_features=sqrt, max_depth=10, min_samples_leaf=5, n_estimators=900
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [CV]  min_samples_split=5, max_features=sqrt, max_depth=10, min_samples_leaf=5, n_estimators=900, total=   0.9s
# [CV] min_samples_split=5, max_features=sqrt, max_depth=10, min_samples_leaf=5, n_estimators=900
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.9s remaining:    0.0s
# [CV]  min_samples_split=5, max_features=sqrt, max_depth=10, min_samples_leaf=5, n_estimators=900, total=   0.9s
# [CV] min_samples_split=5, max_features=sqrt, max_depth=10, min_samples_leaf=5, n_estimators=900
# [CV]  min_samples_split=5, max_features=sqrt, max_depth=10, min_samples_leaf=5, n_estimators=900, total=   0.8s
# [CV] min_samples_split=5, max_features=sqrt, max_depth=10, min_samples_leaf=5, n_estimators=900
# [CV]  min_samples_split=5, max_features=sqrt, max_depth=10, min_samples_leaf=5, n_estimators=900, total=   1.0s
# [CV] min_samples_split=5, max_features=sqrt, max_depth=10, min_samples_leaf=5, n_estimators=900
# [CV]  min_samples_split=5, max_features=sqrt, max_depth=10, min_samples_leaf=5, n_estimators=900, total=   0.9s
# [CV] min_samples_split=10, max_features=sqrt, max_depth=15, min_samples_leaf=2, n_estimators=1100
# [CV]  min_samples_split=10, max_features=sqrt, max_depth=15, min_samples_leaf=2, n_estimators=1100, total=   1.1s
# [CV] min_samples_split=10, max_features=sqrt, max_depth=15, min_samples_leaf=2, n_estimators=1100
# [CV]  min_samples_split=10, max_features=sqrt, max_depth=15, min_samples_leaf=2, n_estimators=1100, total=   1.0s
# [CV] min_samples_split=10, max_features=sqrt, max_depth=15, min_samples_leaf=2, n_estimators=1100
# [CV]  min_samples_split=10, max_features=sqrt, max_depth=15, min_samples_leaf=2, n_estimators=1100, total=   1.0s
# [CV] min_samples_split=10, max_features=sqrt, max_depth=15, min_samples_leaf=2, n_estimators=1100
# [CV]  min_samples_split=10, max_features=sqrt, max_depth=15, min_samples_leaf=2, n_estimators=1100, total=   1.0s
# [CV] min_samples_split=10, max_features=sqrt, max_depth=15, min_samples_leaf=2, n_estimators=1100
# [CV]  min_samples_split=10, max_features=sqrt, max_depth=15, min_samples_leaf=2, n_estimators=1100, total=   1.1s
# [CV] min_samples_split=100, max_features=auto, max_depth=15, min_samples_leaf=5, n_estimators=300
# [CV]  min_samples_split=100, max_features=auto, max_depth=15, min_samples_leaf=5, n_estimators=300, total=   0.3s
# [CV] min_samples_split=100, max_features=auto, max_depth=15, min_samples_leaf=5, n_estimators=300
# [CV]  min_samples_split=100, max_features=auto, max_depth=15, min_samples_leaf=5, n_estimators=300, total=   0.3s
# [CV] min_samples_split=100, max_features=auto, max_depth=15, min_samples_leaf=5, n_estimators=300
# [CV]  min_samples_split=100, max_features=auto, max_depth=15, min_samples_leaf=5, n_estimators=300, total=   0.3s
# [CV] min_samples_split=100, max_features=auto, max_depth=15, min_samples_leaf=5, n_estimators=300
# [CV]  min_samples_split=100, max_features=auto, max_depth=15, min_samples_leaf=5, n_estimators=300, total=   0.3s
# [CV] min_samples_split=100, max_features=auto, max_depth=15, min_samples_leaf=5, n_estimators=300
# [CV]  min_samples_split=100, max_features=auto, max_depth=15, min_samples_leaf=5, n_estimators=300, total=   0.3s
# [CV] min_samples_split=5, max_features=auto, max_depth=15, min_samples_leaf=5, n_estimators=400
# [CV]  min_samples_split=5, max_features=auto, max_depth=15, min_samples_leaf=5, n_estimators=400, total=   0.4s
# [CV] min_samples_split=5, max_features=auto, max_depth=15, min_samples_leaf=5, n_estimators=400
# [CV]  min_samples_split=5, max_features=auto, max_depth=15, min_samples_leaf=5, n_estimators=400, total=   0.4s
# [CV] min_samples_split=5, max_features=auto, max_depth=15, min_samples_leaf=5, n_estimators=400
# [CV]  min_samples_split=5, max_features=auto, max_depth=15, min_samples_leaf=5, n_estimators=400, total=   0.4s
# [CV] min_samples_split=5, max_features=auto, max_depth=15, min_samples_leaf=5, n_estimators=400
# [CV]  min_samples_split=5, max_features=auto, max_depth=15, min_samples_leaf=5, n_estimators=400, total=   0.4s
# [CV] min_samples_split=5, max_features=auto, max_depth=15, min_samples_leaf=5, n_estimators=400
# [CV]  min_samples_split=5, max_features=auto, max_depth=15, min_samples_leaf=5, n_estimators=400, total=   0.4s
# [CV] min_samples_split=5, max_features=auto, max_depth=20, min_samples_leaf=10, n_estimators=700
# [CV]  min_samples_split=5, max_features=auto, max_depth=20, min_samples_leaf=10, n_estimators=700, total=   0.7s
# [CV] min_samples_split=5, max_features=auto, max_depth=20, min_samples_leaf=10, n_estimators=700
# [CV]  min_samples_split=5, max_features=auto, max_depth=20, min_samples_leaf=10, n_estimators=700, total=   0.6s
# [CV] min_samples_split=5, max_features=auto, max_depth=20, min_samples_leaf=10, n_estimators=700
# [CV]  min_samples_split=5, max_features=auto, max_depth=20, min_samples_leaf=10, n_estimators=700, total=   0.6s
# [CV] min_samples_split=5, max_features=auto, max_depth=20, min_samples_leaf=10, n_estimators=700
# [CV]  min_samples_split=5, max_features=auto, max_depth=20, min_samples_leaf=10, n_estimators=700, total=   0.6s
# [CV] min_samples_split=5, max_features=auto, max_depth=20, min_samples_leaf=10, n_estimators=700
# [CV]  min_samples_split=5, max_features=auto, max_depth=20, min_samples_leaf=10, n_estimators=700, total=   0.7s
# [CV] min_samples_split=2, max_features=sqrt, max_depth=25, min_samples_leaf=1, n_estimators=1000
# [CV]  min_samples_split=2, max_features=sqrt, max_depth=25, min_samples_leaf=1, n_estimators=1000, total=   1.0s
# [CV] min_samples_split=2, max_features=sqrt, max_depth=25, min_samples_leaf=1, n_estimators=1000
# [CV]  min_samples_split=2, max_features=sqrt, max_depth=25, min_samples_leaf=1, n_estimators=1000, total=   1.0s
# [CV] min_samples_split=2, max_features=sqrt, max_depth=25, min_samples_leaf=1, n_estimators=1000
# [CV]  min_samples_split=2, max_features=sqrt, max_depth=25, min_samples_leaf=1, n_estimators=1000, total=   0.9s
# [CV] min_samples_split=2, max_features=sqrt, max_depth=25, min_samples_leaf=1, n_estimators=1000
# [CV]  min_samples_split=2, max_features=sqrt, max_depth=25, min_samples_leaf=1, n_estimators=1000, total=   1.0s
# [CV] min_samples_split=2, max_features=sqrt, max_depth=25, min_samples_leaf=1, n_estimators=1000
# [CV]  min_samples_split=2, max_features=sqrt, max_depth=25, min_samples_leaf=1, n_estimators=1000, total=   1.0s
# [CV] min_samples_split=15, max_features=sqrt, max_depth=5, min_samples_leaf=10, n_estimators=1100
# [CV]  min_samples_split=15, max_features=sqrt, max_depth=5, min_samples_leaf=10, n_estimators=1100, total=   0.9s
# [CV] min_samples_split=15, max_features=sqrt, max_depth=5, min_samples_leaf=10, n_estimators=1100
# [CV]  min_samples_split=15, max_features=sqrt, max_depth=5, min_samples_leaf=10, n_estimators=1100, total=   1.0s
# [CV] min_samples_split=15, max_features=sqrt, max_depth=5, min_samples_leaf=10, n_estimators=1100
# [CV]  min_samples_split=15, max_features=sqrt, max_depth=5, min_samples_leaf=10, n_estimators=1100, total=   1.0s
# [CV] min_samples_split=15, max_features=sqrt, max_depth=5, min_samples_leaf=10, n_estimators=1100
# [CV]  min_samples_split=15, max_features=sqrt, max_depth=5, min_samples_leaf=10, n_estimators=1100, total=   1.0s
# [CV] min_samples_split=15, max_features=sqrt, max_depth=5, min_samples_leaf=10, n_estimators=1100
# [CV]  min_samples_split=15, max_features=sqrt, max_depth=5, min_samples_leaf=10, n_estimators=1100, total=   1.0s
# [CV] min_samples_split=15, max_features=sqrt, max_depth=15, min_samples_leaf=1, n_estimators=300
# [CV]  min_samples_split=15, max_features=sqrt, max_depth=15, min_samples_leaf=1, n_estimators=300, total=   0.3s
# [CV] min_samples_split=15, max_features=sqrt, max_depth=15, min_samples_leaf=1, n_estimators=300
# [CV]  min_samples_split=15, max_features=sqrt, max_depth=15, min_samples_leaf=1, n_estimators=300, total=   0.3s
# [CV] min_samples_split=15, max_features=sqrt, max_depth=15, min_samples_leaf=1, n_estimators=300
# [CV]  min_samples_split=15, max_features=sqrt, max_depth=15, min_samples_leaf=1, n_estimators=300, total=   0.3s
# [CV] min_samples_split=15, max_features=sqrt, max_depth=15, min_samples_leaf=1, n_estimators=300
# [CV]  min_samples_split=15, max_features=sqrt, max_depth=15, min_samples_leaf=1, n_estimators=300, total=   0.3s
# [CV] min_samples_split=15, max_features=sqrt, max_depth=15, min_samples_leaf=1, n_estimators=300
# [CV]  min_samples_split=15, max_features=sqrt, max_depth=15, min_samples_leaf=1, n_estimators=300, total=   0.3s
# [CV] min_samples_split=10, max_features=sqrt, max_depth=5, min_samples_leaf=2, n_estimators=700
# [CV]  min_samples_split=10, max_features=sqrt, max_depth=5, min_samples_leaf=2, n_estimators=700, total=   0.6s
# [CV] min_samples_split=10, max_features=sqrt, max_depth=5, min_samples_leaf=2, n_estimators=700
# [CV]  min_samples_split=10, max_features=sqrt, max_depth=5, min_samples_leaf=2, n_estimators=700, total=   0.6s
# [CV] min_samples_split=10, max_features=sqrt, max_depth=5, min_samples_leaf=2, n_estimators=700
# [CV]  min_samples_split=10, max_features=sqrt, max_depth=5, min_samples_leaf=2, n_estimators=700, total=   0.6s
# [CV] min_samples_split=10, max_features=sqrt, max_depth=5, min_samples_leaf=2, n_estimators=700
# [CV]  min_samples_split=10, max_features=sqrt, max_depth=5, min_samples_leaf=2, n_estimators=700, total=   0.6s
# [CV] min_samples_split=10, max_features=sqrt, max_depth=5, min_samples_leaf=2, n_estimators=700
# [CV]  min_samples_split=10, max_features=sqrt, max_depth=5, min_samples_leaf=2, n_estimators=700, total=   0.6s
# [CV] min_samples_split=15, max_features=auto, max_depth=20, min_samples_leaf=1, n_estimators=700
# [CV]  min_samples_split=15, max_features=auto, max_depth=20, min_samples_leaf=1, n_estimators=700, total=   0.7s
# [CV] min_samples_split=15, max_features=auto, max_depth=20, min_samples_leaf=1, n_estimators=700
# [CV]  min_samples_split=15, max_features=auto, max_depth=20, min_samples_leaf=1, n_estimators=700, total=   0.7s
# [CV] min_samples_split=15, max_features=auto, max_depth=20, min_samples_leaf=1, n_estimators=700
# [CV]  min_samples_split=15, max_features=auto, max_depth=20, min_samples_leaf=1, n_estimators=700, total=   0.7s
# [CV] min_samples_split=15, max_features=auto, max_depth=20, min_samples_leaf=1, n_estimators=700
# [CV]  min_samples_split=15, max_features=auto, max_depth=20, min_samples_leaf=1, n_estimators=700, total=   0.7s
# [CV] min_samples_split=15, max_features=auto, max_depth=20, min_samples_leaf=1, n_estimators=700
# [CV]  min_samples_split=15, max_features=auto, max_depth=20, min_samples_leaf=1, n_estimators=700, total=   0.7s
# [Parallel(n_jobs=1)]: Done  50 out of  50 | elapsed:   33.8s finished
# RandomizedSearchCV(cv=5, error_score=nan,
#                    estimator=RandomForestRegressor(bootstrap=True,
#                                                    ccp_alpha=0.0,
#                                                    criterion='mse',
#                                                    max_depth=None,
#                                                    max_features='auto',
#                                                    max_leaf_nodes=None,
#                                                    max_samples=None,
#                                                    min_impurity_decrease=0.0,
#                                                    min_impurity_split=None,
#                                                    min_samples_leaf=1,
#                                                    min_samples_split=2,
#                                                    min_weight_fraction_leaf=0.0,
#                                                    n_estimators=100,
#                                                    n_jobs=None, oob_score=Fals...
#                    iid='deprecated', n_iter=10, n_jobs=1,
#                    param_distributions={'max_depth': [5, 10, 15, 20, 25, 30],
#                                         'max_features': ['auto', 'sqrt'],
#                                         'min_samples_leaf': [1, 2, 5, 10],
#                                         'min_samples_split': [2, 5, 10, 15,
#                                                               100],
#                                         'n_estimators': [100, 200, 300, 400,
#                                                          500, 600, 700, 800,
#                                                          900, 1000, 1100,
#                                                          1200]},
#                    pre_dispatch='2*n_jobs', random_state=42, refit=True,
#                    return_train_score=False, scoring='neg_mean_squared_error',
#                    verbose=2)

# %%
rf_random.best_params_
# Out:
# {'max_depth': 25,
#  'max_features': 'sqrt',
#  'min_samples_leaf': 1,
#  'min_samples_split': 2,
#  'n_estimators': 1000}

# %%
predictions=rf_random.predict(X_test)

# %%
sns.distplot(Y_test-predictions)

# %%
plt.scatter(Y_test,predictions)

# %%
import pickle
# open a file, where you ant to store the data
file = open('random_forest_regression_model.pkl', 'wb')

# dump information to that file
pickle.dump(rf_random, file)
